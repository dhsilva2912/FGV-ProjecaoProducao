# %% [markdown]
# <img src="img/logo-pirelli-dsa.png" align="left"/>
# <br>
#
# # Projeção de Produção - Modelo Preditivo Dados 2018
# ***
# **Integrantes Grupo:**
# <br>Danillo Silva
# <br>Diego Dantas
# <br>Gustavo Sainatto
# <br>Nestor Soken
# <br>Rubia Quinteiro Nierotka
#
# Travou em 2018-04-22 23:00:00

# %% [markdown]
# ### Bibliotecas:
# ***

# %%
import pandas as pd
import numpy as np
import datetime as dt

from statsmodels.tsa.stattools import adfuller
from sklearn import metrics

from math import sqrt
from math import pi

from pmdarima.arima import auto_arima

# %% [markdown]
# ### Carregar Base de Dados Historicos:
# ***

# %%
df_base = pd.read_parquet('prod_hist.parquet')
df_base = df_base[['EVS_END', 'MCH_NUMBER', 'EVS_REAL_QTY']]

df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3693833 entries, 0 to 3693832
# Data columns (total 3 columns):
# EVS_END         datetime64[ns]
# MCH_NUMBER      object
# EVS_REAL_QTY    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 112.7+ MB

# %% [markdown]
# ### Definir Funcao de Teste Para o Modelo:
# ***

# %%
def forecast_2018(interval, df_base):
    turnos = 3
    tempo_turno = (8 * 60)

    turno_atual = pd.to_datetime(interval)
    turno_passado = turno_atual - dt.timedelta(minutes=(tempo_turno * turnos))
    turno_futuro = turno_atual + dt.timedelta(minutes=tempo_turno)

    print('Processando Turno : {}'.format(turno_atual))

    df_series = df_base.loc[(df_base['EVS_END'] >= turno_passado) & (df_base['EVS_END'] < turno_atual)]

    df_series = df_series.groupby(by=['MCH_NUMBER', pd.Grouper(key='EVS_END', freq='5Min')]).sum()
    df_series = df_series.unstack('MCH_NUMBER')
    df_series.fillna(value=0, inplace=True)
    df_series.columns = df_series.columns.droplevel()

    adf = dict(zip(df_series.columns.tolist(),
                   [True if (adfuller(df_series[col])[1] < 0.05) else False for col in df_series.columns.tolist()]))

    model ={}
    for i in range(df_series.columns.size):
        maq = df_series.columns[i]
        
        print(maq)
        
        arima_model = auto_arima(df_series[maq], seasonal=True, stationary=adf[maq],trace=False,
                                 error_action='ignore',suppress_warnings=True, stepwise=True)
        
        model[maq] = [arima_model]

    df_model =  pd.DataFrame.from_dict(model, orient='index', columns=['model'])
    period = pd.date_range(start= turno_atual, end= turno_futuro, freq='5Min')

    pred = {}
    for i in range(df_model.shape[0]):
        pred[df_model.index[i]] = df_model['model'][i].predict(n_periods=period.size)

    df_forecast =  pd.DataFrame.from_dict(pred)
    df_forecast.index = period

    final = {}
    
    df_real = df_base.loc[(df_base['EVS_END'] >= turno_atual) & (df_base['EVS_END'] < turno_futuro)]

    df_real = df_real.groupby(by=['MCH_NUMBER', pd.Grouper(key='EVS_END', freq='5Min')]).sum()
    df_real = df_real.unstack('MCH_NUMBER')
    df_real.fillna(value=0, inplace=True)
    df_real.columns = df_real.columns.droplevel()
    
    for i in range(df_forecast.columns.size):
        try:
            final[df_forecast.columns[i]] = [turno_atual,
                                             df_forecast[df_forecast.columns[i]].tolist(),
                                             df_real[df_forecast.columns[i]].tolist()]
        except:
            final[df_forecast.columns[i]] = [turno_atual, 0, 0]

    df_final = pd.DataFrame.from_dict(final, orient='index', columns=['DATA', 'FORECAST', 'REAL'])
       
    return df_final

# %%
#pd.to_datetime(dt.datetime(2018,3,5,7))

data_inicio = pd.to_datetime(dt.datetime(2018,3,5,7))
data_final =  pd.to_datetime(dt.datetime(2018,12,31,23))

interval = pd.date_range(start= data_inicio,
                         end=   data_final,
                         freq='480Min').astype(str).tolist()

# %%
result =[]
for i in range(len(interval)):
    result.append(forecast_2018(interval[i],df_base))
# Out:
# Processando Turno : 2018-03-05 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-05 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-05 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-06 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-06 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-06 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-07 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-07 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-07 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-08 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-08 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-08 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-09 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-09 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-09 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-10 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-10 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-10 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-11 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-11 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-11 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-12 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-12 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-12 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-13 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-13 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-13 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-14 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-14 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-14 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-15 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-15 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-15 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-16 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-16 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-16 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-17 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-17 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-17 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-18 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-18 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-18 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-19 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-19 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-19 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-20 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-20 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-20 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-21 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-21 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-21 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-22 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-22 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-22 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-23 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-23 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-23 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-24 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-24 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-24 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-25 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-25 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-25 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-26 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-26 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-26 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-27 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-27 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-27 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-28 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-28 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-28 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-29 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-29 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-29 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-30 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-30 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-30 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-31 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# V01
# V02
# V03
# V04
# V06
# V07
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-31 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-03-31 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-01 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-01 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-01 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-02 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-02 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-02 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-03 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-03 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-03 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-04 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-04 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-04 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-05 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-05 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-05 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-06 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-06 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-06 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-07 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-07 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-07 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-08 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-08 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-08 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-09 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-09 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-09 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-10 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-10 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-10 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-11 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-11 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-11 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-12 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-12 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-12 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-13 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-13 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-13 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-14 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-14 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-14 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-15 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-15 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-15 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-16 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-16 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-16 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-17 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-17 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-17 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-18 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-18 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-18 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-19 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-19 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-19 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-20 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-20 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-20 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-21 07:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-21 15:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-21 23:00:00
# AM1
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-22 07:00:00
# AM1
# C:\Users\silvada010\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# AM2
# AM3
# AM4
# TL1
# TR1
# TR2
# V01
# V02
# V03
# V04
# V05
# V06
# V07
# V08
# V09
# V10
# V11
# V12
# Processando Turno : 2018-04-22 15:00:00
# V01
# C:\Users\silvada010\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# V02
# V03
# V06
# V07
# V12
# Processando Turno : 2018-04-22 23:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c43f797ac1af> in <module>
#       2 result =[]
#       3 for i in range(len(interval)):
# ----> 4     result.append(forecast_2018(interval[i],df_base))
#
# <ipython-input-3-8f815538730e> in forecast_2018(interval, df_base)
#      38
#      39     df_forecast =  pd.DataFrame.from_dict(pred)
# ---> 40     df_forecast.index = period
#      41
#      42     final = {}
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 97 elements

# %%
df_final = pd.concat(result)

# %%
df_final[df_final['FORECAST']==0]

# %%
df_final.to_parquet('results_2018.parquet')
